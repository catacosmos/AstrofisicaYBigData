# %% [markdown]
# # Clasificación con redes neuronales
#
# En este notebook simple usaremos una FCNN (completamente conectada) para resolver el problema de clasificación de ID de partículas, visto previamente para SVMs.
#
# Basado en Machine learning for physics and Astronomy, Viviana Acquaviva (2023)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.utils import shuffle

# %%
import matplotlib
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 150)

font = {'size'   : 16}
matplotlib.rc('font', **font)
matplotlib.rc('xtick', labelsize=14)
matplotlib.rc('ytick', labelsize=14)
matplotlib.rcParams['figure.dpi'] = 300

# %% [markdown]
# ### Librerías para Deep Learning
#
# [Tensorflow](https://www.tensorflow.org/?hl=es-419) es una biblioteca de uso muy común para el desarrollo de modelos de aprendizaje profundo. Es una plataforma de código abierto desarrollada por Google. Admite programación en varios lenguajes, como C++, Java, Python, y muchos otros.
#
# [Keras](https://keras.io/) es una API de alto nivel (Application Programming Interface) construida sobre TensorFlow (o Theano, otra biblioteca de aprendizaje profundo). Es específica para Python, y podemos pensar en ella como el equivalente de la biblioteca sklearn, pero para redes neuronales. Es menos general y menos personalizable, pero muy fácil de usar y comparativamente más sencilla que TensorFlow.
#
# [PyTorch](https://pytorch.org/) es otra biblioteca muy popular para el desarrollo de modelos de aprendizaje profundo, desarrollada por Meta (Facebook). A diferencia de Keras, no es una API de alto nivel sobre otra biblioteca, sino un framework completo en sí mismo. Es especialmente popular en investigación por su flexibilidad para construir arquitecturas no estándar, aunque eso viene con una curva de aprendizaje más pronunciada y bastante más código para tareas simples.
#
# En este curso usaremos Keras con TensorFlow como back-end, porque para los problemas que veremos su simplicidad tiene más peso que la flexibilidad extra de PyTorch.

# %% [markdown]
# **Comparación**
#
# | | TensorFlow | Keras | PyTorch |
# |---|---|---|---|
# | **Qué es** | Framework completo | API de alto nivel (sobre TensorFlow) | Framework completo |
# | **Desarrollado por** | Google | Ahora integrado a TensorFlow | Meta (Facebook) |
# | **Curva de aprendizaje** | Media-alta | Baja | Media-alta |
# | **Líneas de código para un modelo simple** | Muchas | Pocas | Muchas |
# | **Flexibilidad para arquitecturas no estándar** | Alta | Media | Muy alta |
# | **Dónde se usa más** | Producción, industria | Prototipado rápido, docencia | Investigación, papers recientes |

# %%
import sys
print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.82.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.6.17)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.20.0'

# %% [markdown]
# Importamos `keras` y usaremos `Sequential`, que admite una entrada y una salida

# %%
import keras

from keras.models import Sequential # El modelo se construye agregando una capa después de otra

from keras.layers import Dense #totalmente conectadas: cada output se conecta con cada input

from keras.layers import Dropout #para regularización

# %% [markdown]
# Comenzamos con el problema de 4top vs ttbar, y utilizamos la configuración en la que añadimos las características "número de leptones", "número de jets", etc. Como referencia, el SVM óptimo alcanzó un 94-95% de precisión. Cabe destacar que esos números no se obtuvieron utilizando validación cruzada anidada, por lo que podrían ser ligeramente optimistas.

# %%
X = pd.read_csv('/content/drive/MyDrive/Features_lim_2.csv')

# %%
y = np.genfromtxt('/content/drive/MyDrive/Labels_lim_2.txt')

# %%
X.values.shape
# Out:
# (5000, 24)

# %%
X.head()
# Out:
#    ID      MET    METphi        P1        P2        P3        P4        P5  \
# 0   0  62803.5 -1.810010  137571.0  128444.0 -0.345744 -0.307112  174209.0
# 1   1  57594.2 -0.509253  161529.0   80458.3 -1.318010  1.402050  291490.0
# 2   2  82313.3  1.686840  167130.0  113078.0  0.937258 -2.068680  102423.0
# 3   3  30610.8  2.617120  112267.0   61383.9 -1.211050 -1.457800   40647.8
# 4   4  45153.1 -2.241350  178174.0  100164.0  1.166880 -0.018721   92351.3
#
#          P6        P7        P8        P9      P10       P11       P12  \
# 0  127932.0  0.826569  2.332000   86788.9  84554.9 -0.180795  2.187970
# 1   68462.9 -2.126740 -2.582310   44270.1  35139.6 -0.706120 -0.371392
# 2   54922.3  1.226850  0.646589   60768.9  36244.3  1.102890 -1.434480
# 3   39472.0 -0.024646 -2.222800  201589.0  32978.6 -2.496040  1.137810
# 4   69762.1  0.774114  2.568740   61625.2  50086.7  0.652572 -3.012800
#
#         P13      P14      P15       P16  Total_products  Total_b  Total_j  \
# 0  140289.0  76955.8 -1.19933 -1.302800               5        1        3
# 1   72883.9  26902.2 -1.65386 -3.129630               4        0        2
# 2   77714.0  27801.5  1.68461  1.389690               5        1        4
# 3   90096.7  26964.5  1.87132  0.817631               5        1        4
# 4  104193.0  31151.0  1.87641  0.865381               5        0        5
#
#    Total_g  Total_leptons
# 0        0              1
# 1        0              2
# 2        0              0
# 3        0              0
# 4        0              0

# %%
y
# Out:
# array([0., 0., 0., ..., 0., 1., 0.])

# %% [markdown]
# Aquí no hay un proceso de validación cruzada "integrado", por lo que tendríamos que implementarlo nosotros mismos. Por ahora, podemos construir tres conjuntos: entrenamiento, validación (para la optimización de parámetros) y prueba (para la evaluación final). Idealmente, deberíamos estructurarlo como una validación cruzada.
#
# En la práctica, rara vez se hace CV k-fold completa con redes neuronales. Cada fold implica reentrenar la red desde cero, así que el costo computacional escala rápido: con 5 folds ya estamos pagando 5 veces el costo de entrenamiento, y eso antes de siquiera empezar a buscar hiperparámetros. Además, la razón principal para usar CV es obtener una estimación confiable del desempeño cuando el dataset es chico; con datasets grandes (el escenario típico donde las NN funcionan mejor), un solo split bien hecho ya da una estimación razonablemente estable.
#
# Por eso optamos por un split fijo train/validación/prueba, y usamos el set de validación para *early stopping* y ajuste de hiperparámetros. Esto evita el costo de CV sin sacrificar demasiado rigor.

# %% [markdown]
# #### Sets de entrenamiento y prueba
#
# Este dataset tiene un desbalance importante entre las dos clases. Para que esa proporción se mantenga en cada split, usamos `stratify` al dividir los datos.

# %%
clase, total = np.unique(y, return_counts=True)
print(dict(zip(clase, total)))
# Out:
# {np.float64(0.0): np.int64(4189), np.float64(1.0): np.int64(811)}

# %%
razon = total[1] / total[0]
print(f"Razón: {razon:.2f}")
# Out:
# Razón: 0.19

# %%
# Primero separamos test (20%), estratificado por clase
X_temp, X_test, y_temp, y_test = train_test_split(
    X.values, y, test_size=0.2, stratify=y, random_state=10
)

# Del resto, separamos train/val (80/20 de lo que queda)
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.2, stratify=y_temp, random_state=10
)

print(X_train.shape, X_val.shape, X_test.shape)
print("Balance train:", y_train.mean(), "| val:", y_val.mean(), "| test:", y_test.mean())
# Out:
# (3200, 24) (800, 24) (1000, 24)
# Balance train: 0.1621875 | val: 0.1625 | test: 0.162

# %% [markdown]
# ### Construyendo la red

# %% [markdown]
# Pensemos en la arquitectura del modelo.
#
# Nuestra capa de entrada tiene **24 neuronas** (24 características)
#
# Nuestra capa de salida tiene **una neurona** (la salida es la probabilidad de que el objeto pertenezca a la clase positiva). También podríamos configurarla con dos neuronas (y usar softmax como la no linealidad final), pero esto es redundante en un problema de clasificación binaria. La neurona de salida será una función **sigmoide**
#
# Añadiremos **dos capas ocultas**. En este caso, ambas tienen tamaño = 20 (debemos optimizar este hiperparámetro!). También podemos reservar la posibilidad de añadir una capa de dropout después de cada una.
#
# Otras decisiones que debemos tomar son: qué no linealidades usar (por ahora: ReLU para las capas ocultas, sigmoide para la final), qué optimizador usar (Adam), qué tasa de aprendizaje inicial adoptar (aquí 0.001, aunque nuevamente esto debería decidirse mediante CV), el número de épocas (por ejemplo, 100; podemos graficar cantidades de interés para verificar que esto sea suficiente), el tamaño de lote (batch size) para el paso de descenso por gradiente (aquí 200, pero podemos explorarlo!) y la función de pérdida. Esta última es la entropía cruzada binaria ([binary cross entropy](https://towardsdatascience.com/understanding-binary-cross-entropy-log-loss-a-visual-explanation-a3ac6025181a)), que es la elección estándar para problemas de clasificación donde la salida es una probabilidad. Premia la "confianza" en una predicción correcta (alta probabilidad).

# %% [markdown]
# El siguiente comando nos ayuda a explorar todas las posibles opciones

# %%
dir(keras.optimizers)
# Out:
# ['Adadelta',
#  'Adafactor',
#  'Adagrad',
#  'Adam',
#  'AdamW',
#  'Adamax',
#  'Ftrl',
#  'Lamb',
#  'Lion',
#  'LossScaleOptimizer',
#  'Muon',
#  'Nadam',
#  'Optimizer',
#  'RMSprop',
#  'SGD',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'deserialize',
#  'get',
#  'legacy',
#  'schedules',
#  'serialize']

# %%
dir(keras.losses)
# Out:
# ['BinaryCrossentropy',
#  'BinaryFocalCrossentropy',
#  'CTC',
#  'CategoricalCrossentropy',
#  'CategoricalFocalCrossentropy',
#  'CategoricalGeneralizedCrossEntropy',
#  'CategoricalHinge',
#  'Circle',
#  'CosineSimilarity',
#  'Dice',
#  'Hinge',
#  'Huber',
#  'KLDivergence',
#  'LogCosh',
#  'Loss',
#  'MeanAbsoluteError',
#  'MeanAbsolutePercentageError',
#  'MeanSquaredError',
#  'MeanSquaredLogarithmicError',
#  'Poisson',
#  'SparseCategoricalCrossentropy',
#  'SquaredHinge',
#  'Tversky',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'binary_crossentropy',
#  'binary_focal_crossentropy',
#  'categorical_crossentropy',
#  'categorical_focal_crossentropy',
#  'categorical_generalized_cross_entropy',
#  'categorical_hinge',
#  'circle',
#  'cosine_similarity',
#  'ctc',
#  'deserialize',
#  'dice',
#  'get',
#  'hinge',
#  'huber',
#  'kl_divergence',
#  'log_cosh',
#  'mean_absolute_error',
#  'mean_absolute_percentage_error',
#  'mean_squared_error',
#  'mean_squared_logarithmic_error',
#  'poisson',
#  'serialize',
#  'sparse_categorical_crossentropy',
#  'squared_hinge',
#  'tversky']

# %% [markdown]
# La opción estándar para un caso como el nuestro, donde las etiquetas son 0/1, pero podemos predecir una probabilidad, es binary cross-entropy or log loss:
#
# L = - $\frac{1}{N} \sum_{i=1}^N y_i \cdot log(p(y_i)) + (1-y_i) \cdot log (1 - p(y_i))$

# %% [markdown]
# $p$ es la probabilidad de que un objeto pertenezca a la clase positiva. Penaliza los ejemplos positivos que están asociados con una probabilidad predicha baja, y los ejemplos negativos que están asociados con una probabilidad predicha alta.

# %% [markdown]
# Acá una lista de funciones de activación

# %%
dir(keras.activations)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'celu',
#  'deserialize',
#  'elu',
#  'exponential',
#  'gelu',
#  'get',
#  'glu',
#  'hard_shrink',
#  'hard_sigmoid',
#  'hard_silu',
#  'hard_swish',
#  'hard_tanh',
#  'leaky_relu',
#  'linear',
#  'log_sigmoid',
#  'log_softmax',
#  'mish',
#  'relu',
#  'relu6',
#  'selu',
#  'serialize',
#  'sigmoid',
#  'silu',
#  'soft_shrink',
#  'softmax',
#  'softplus',
#  'softsign',
#  'sparse_plus',
#  'sparse_sigmoid',
#  'sparsemax',
#  'squareplus',
#  'swish',
#  'tanh',
#  'tanh_shrink',
#  'threshold']

# %% [markdown]
# ### Así es como construímos la red completamente conectada en Keras

# %%
model = Sequential()

# Primera capa oculta, especificamos el tamaño del input (número de características originales)

model.add(Dense(20, activation='relu', input_shape=(24,)))

# Agrega una  segunda capa oculta y especificamos el tamaño

model.add(Dense(20, activation='relu'))

# Agrega capa de salida

model.add(Dense(1, activation='sigmoid'))

model.summary() # resumen de la arquitectura
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (None, 20)             │           500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 941 (3.68 KB)
#  Trainable params: 941 (3.68 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy'])

# %% [markdown]
# Con el keyword `métrica` podemos cambiar a la métrica que queremos ver. El valor absoluto de la pérdida no se traduce directamente en algo intuitivo (a diferencia de accuracy, que sí es un % de aciertos), aunque sigue siendo muy útil para comparar train vs. validación y detectar overfitting.

# %% [markdown]
# ### Ahora pruebe usted
#
# Usando el mismo código de arriba como plantilla, modifíquelo para responder:
#
# **¿Qué pasa si agrega una tercera capa oculta?** Agréguela (por ejemplo, de tamaño 20 también) y comenten: ¿por qué una arquitectura más profunda podría ayudar o no ayudar en este problema?
#     Respuesta: Aumenta los parámetros. Podría ayudar si el problema es muy complejo, pero para este dataset pequeño, puede causar sobreajuste y lentitud sin mejorar mucho.
#
#
# **¿Qué pasa si cambia el tamaño de las capas ocultas** (por ejemplo, de 20 a 5, o de 20 a 100)? Antes de correrlo: ¿espera que la red sea más lenta o más rápida de entrenar? ¿Más o menos propensa a sobreajustar?
#     Respuesta: Con 5 neuronas entrenará más rápido, será menos propensa a sobreajuste (pero con riesgo de subajuste). Con 100 neuronas entrenará más lento, será más propensa a sobreajuste.
#
#
# **¿Qué pasa si usa otra función de activación** en las capas ocultas (por ejemplo `tanh` en vez de `relu`)? Revise la lista de activaciones disponibles que exploramos arriba con `dir(keras.activations)`.
#     Respuesta: No cambia los parámetros. tanh (salida entre -1 y 1) puede sufrir de gradientes desvanecientes, lo que podría hacer el entrenamiento más lento o menos eficaz que relu (que evita este problema para valores positivos).
#
# No hace falta entrenar todavía, solo construyan el modelo con `model.summary()` al final y observe cómo cambia el número de parámetros totales según sus decisiones.

# %% [markdown]
# ### Variante 1: Agregando una tercera capa oculta

# %%
model_three_layers = Sequential()

# Primera capa oculta
model_three_layers.add(Dense(20, activation='relu', input_shape=(24,)))

# Segunda capa oculta
model_three_layers.add(Dense(20, activation='relu'))

# Tercera capa oculta
model_three_layers.add(Dense(20, activation='relu'))

# Capa de salida
model_three_layers.add(Dense(1, activation='sigmoid'))

model_three_layers.summary() # resumen de la arquitectura
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                │ (None, 20)             │           500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,361 (5.32 KB)
#  Trainable params: 1,361 (5.32 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Variante 2: Cambiando el tamaño de las capas ocultas (5 neuronas)
#
# Vamos a construir una red con capas ocultas mucho más pequeñas (5 neuronas) para ver cómo afecta la complejidad del modelo.

# %%
model_small_layers = Sequential()

# Primera capa oculta con 5 neuronas
model_small_layers.add(Dense(5, activation='relu', input_shape=(24,)))

# Segunda capa oculta con 5 neuronas
model_small_layers.add(Dense(5, activation='relu'))

# Capa de salida
model_small_layers.add(Dense(1, activation='sigmoid'))

model_small_layers.summary() # resumen de la arquitectura
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_14 (Dense)                │ (None, 5)              │           125 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 5)              │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 161 (644.00 B)
#  Trainable params: 161 (644.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Variante 3: Cambiando el tamaño de las capas ocultas (100 neuronas)
#
# Ahora, probemos con capas ocultas mucho más grandes (100 neuronas) para observar el impacto en el número de parámetros y la complejidad.

# %%
model_large_layers = Sequential()

# Primera capa oculta con 100 neuronas
model_large_layers.add(Dense(100, activation='relu', input_shape=(24,)))

# Segunda capa oculta con 100 neuronas
model_large_layers.add(Dense(100, activation='relu'))

# Capa de salida
model_large_layers.add(Dense(1, activation='sigmoid'))

model_large_layers.summary() # resumen de la arquitectura
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_17 (Dense)                │ (None, 100)            │         2,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,701 (49.61 KB)
#  Trainable params: 12,701 (49.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Variante 4: Cambiando la función de activación (tanh)
#
# Finalmente, experimentemos con la función de activación `tanh` en lugar de `relu` para las capas ocultas.

# %%
model_tanh_activation = Sequential()

# Primera capa oculta con activación tanh
model_tanh_activation.add(Dense(20, activation='tanh', input_shape=(24,)))

# Segunda capa oculta con activación tanh
model_tanh_activation.add(Dense(20, activation='tanh'))

# Capa de salida
model_tanh_activation.add(Dense(1, activation='sigmoid'))

model_tanh_activation.summary() # resumen de la arquitectura
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_20 (Dense)                │ (None, 20)             │           500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 941 (3.68 KB)
#  Trainable params: 941 (3.68 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Listos para ajustar!
#
# Nota también los hiperparámetros adicionales "epochs" (el número de pasadas completas de ida y vuelta sobre el conjunto de datos) y "batch size" (cuántos datos se utilizan en cada paso para actualizar los pesos).

# %% [markdown]
# ### Antes de correr esto
#
# ¿Qué accuracy espera que logre esta red? Como referencia, el SVM óptimo llegó a 94-95%. Escriba su predicción antes de correr la celda de abajo.
#
# > Mi predicción de accuracy: ~75%, dado que los datos aún no están escalados, es probable que rinda mucho peor que el SVM óptimo con datos escalados.

# %%
mynet = model.fit(X_train, y_train, validation_data= (X_val, y_val), epochs = 100,  batch_size=200)
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.8328 - loss: 24733.1152 - val_accuracy: 0.8000 - val_loss: 12203.9189
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6706 - loss: 10554.9053 - val_accuracy: 0.6575 - val_loss: 8337.4326
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7103 - loss: 7250.5371 - val_accuracy: 0.7287 - val_loss: 6055.2607
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6956 - loss: 5341.0181 - val_accuracy: 0.7025 - val_loss: 4481.3716
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6856 - loss: 3938.2529 - val_accuracy: 0.6550 - val_loss: 3339.3127
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6869 - loss: 3031.9900 - val_accuracy: 0.6550 - val_loss: 2448.5627
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6878 - loss: 2372.9922 - val_accuracy: 0.6313 - val_loss: 1884.6375
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6684 - loss: 1939.2041 - val_accuracy: 0.6875 - val_loss: 1591.7041
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6850 - loss: 1714.9044 - val_accuracy: 0.6725 - val_loss: 1464.0044
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6872 - loss: 1525.8257 - val_accuracy: 0.6687 - val_loss: 1316.1216
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6791 - loss: 1376.1914 - val_accuracy: 0.6988 - val_loss: 1224.7421
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6900 - loss: 1287.7281 - val_accuracy: 0.6938 - val_loss: 1099.3320
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6841 - loss: 1180.1232 - val_accuracy: 0.6538 - val_loss: 1023.3181
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6869 - loss: 1059.0197 - val_accuracy: 0.7250 - val_loss: 930.0168
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6944 - loss: 974.0168 - val_accuracy: 0.7025 - val_loss: 905.2601
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6981 - loss: 888.5773 - val_accuracy: 0.6950 - val_loss: 831.4318
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6941 - loss: 839.0144 - val_accuracy: 0.6600 - val_loss: 789.2972
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7031 - loss: 785.9290 - val_accuracy: 0.6812 - val_loss: 712.3289
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7069 - loss: 694.3583 - val_accuracy: 0.7362 - val_loss: 693.5710
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7003 - loss: 671.0461 - val_accuracy: 0.7750 - val_loss: 726.1819
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7231 - loss: 635.4709 - val_accuracy: 0.7538 - val_loss: 662.0235
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7163 - loss: 560.5862 - val_accuracy: 0.7100 - val_loss: 557.2360
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7228 - loss: 551.2115 - val_accuracy: 0.7337 - val_loss: 578.9702
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7209 - loss: 543.6132 - val_accuracy: 0.6725 - val_loss: 542.9533
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7262 - loss: 465.5899 - val_accuracy: 0.6712 - val_loss: 530.1139
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7178 - loss: 466.8138 - val_accuracy: 0.7362 - val_loss: 465.7606
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7312 - loss: 469.1613 - val_accuracy: 0.6463 - val_loss: 518.3234
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7312 - loss: 422.0858 - val_accuracy: 0.7050 - val_loss: 410.5477
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7422 - loss: 396.1366 - val_accuracy: 0.7563 - val_loss: 453.3387
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7409 - loss: 377.4332 - val_accuracy: 0.7175 - val_loss: 421.3729
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7428 - loss: 367.1976 - val_accuracy: 0.7513 - val_loss: 389.2684
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7484 - loss: 351.1940 - val_accuracy: 0.7013 - val_loss: 419.7999
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7456 - loss: 378.3183 - val_accuracy: 0.7788 - val_loss: 466.2955
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7516 - loss: 367.2766 - val_accuracy: 0.6900 - val_loss: 378.1737
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7497 - loss: 352.3771 - val_accuracy: 0.7638 - val_loss: 396.4605
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7513 - loss: 348.7289 - val_accuracy: 0.5675 - val_loss: 533.6136
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7375 - loss: 350.8293 - val_accuracy: 0.7750 - val_loss: 361.7495
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7556 - loss: 301.2971 - val_accuracy: 0.7538 - val_loss: 315.2065
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7584 - loss: 281.4933 - val_accuracy: 0.7563 - val_loss: 348.8719
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7356 - loss: 337.6111 - val_accuracy: 0.7462 - val_loss: 309.7349
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7581 - loss: 369.4365 - val_accuracy: 0.7525 - val_loss: 323.6353
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7456 - loss: 286.1190 - val_accuracy: 0.7475 - val_loss: 293.2429
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7556 - loss: 269.0832 - val_accuracy: 0.7613 - val_loss: 300.3618
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7672 - loss: 255.2577 - val_accuracy: 0.7237 - val_loss: 267.3418
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7416 - loss: 281.1774 - val_accuracy: 0.6800 - val_loss: 321.3264
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7575 - loss: 237.1096 - val_accuracy: 0.7400 - val_loss: 265.2492
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7412 - loss: 254.2187 - val_accuracy: 0.7025 - val_loss: 279.7936
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7653 - loss: 239.2578 - val_accuracy: 0.6538 - val_loss: 324.7289
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7625 - loss: 223.0635 - val_accuracy: 0.7262 - val_loss: 255.4946
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7600 - loss: 237.7595 - val_accuracy: 0.7850 - val_loss: 287.5018
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7456 - loss: 260.4559 - val_accuracy: 0.7513 - val_loss: 235.8393
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7594 - loss: 211.8166 - val_accuracy: 0.6862 - val_loss: 268.2791
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7447 - loss: 247.5958 - val_accuracy: 0.7337 - val_loss: 237.4854
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7666 - loss: 205.7615 - val_accuracy: 0.6625 - val_loss: 311.2379
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7613 - loss: 226.9154 - val_accuracy: 0.7063 - val_loss: 241.4863
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7634 - loss: 196.3394 - val_accuracy: 0.7688 - val_loss: 242.5077
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7634 - loss: 208.3784 - val_accuracy: 0.7188 - val_loss: 251.1877
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7619 - loss: 224.3685 - val_accuracy: 0.6862 - val_loss: 259.1650
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7703 - loss: 203.8995 - val_accuracy: 0.7887 - val_loss: 258.9097
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7600 - loss: 226.8104 - val_accuracy: 0.8037 - val_loss: 322.8956
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7622 - loss: 207.1256 - val_accuracy: 0.7775 - val_loss: 248.1978
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7578 - loss: 185.3863 - val_accuracy: 0.7788 - val_loss: 241.1656
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7659 - loss: 178.0990 - val_accuracy: 0.7287 - val_loss: 209.1556
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7675 - loss: 185.0055 - val_accuracy: 0.7362 - val_loss: 212.5406
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7494 - loss: 228.3779 - val_accuracy: 0.7100 - val_loss: 229.6804
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7347 - loss: 228.5745 - val_accuracy: 0.7250 - val_loss: 226.9799
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7578 - loss: 192.2861 - val_accuracy: 0.6975 - val_loss: 213.6370
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7659 - loss: 169.1066 - val_accuracy: 0.8050 - val_loss: 230.8252
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7516 - loss: 199.2514 - val_accuracy: 0.8125 - val_loss: 323.3480
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7437 - loss: 211.7661 - val_accuracy: 0.8025 - val_loss: 260.3884
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7681 - loss: 173.9350 - val_accuracy: 0.6812 - val_loss: 239.8952
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7538 - loss: 175.4143 - val_accuracy: 0.8125 - val_loss: 227.2554
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7534 - loss: 205.0845 - val_accuracy: 0.8138 - val_loss: 359.7971
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7478 - loss: 240.3260 - val_accuracy: 0.7650 - val_loss: 224.5532
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7778 - loss: 174.3388 - val_accuracy: 0.7138 - val_loss: 195.5165
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7688 - loss: 161.4727 - val_accuracy: 0.7975 - val_loss: 218.5910
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7469 - loss: 197.1766 - val_accuracy: 0.8000 - val_loss: 215.1616
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7703 - loss: 161.6509 - val_accuracy: 0.7175 - val_loss: 211.2471
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7341 - loss: 220.5340 - val_accuracy: 0.6137 - val_loss: 309.2563
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7459 - loss: 210.3574 - val_accuracy: 0.6737 - val_loss: 228.2081
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7600 - loss: 187.4573 - val_accuracy: 0.6350 - val_loss: 285.9852
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7525 - loss: 199.6895 - val_accuracy: 0.7525 - val_loss: 198.2570
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7675 - loss: 156.1063 - val_accuracy: 0.7237 - val_loss: 193.0401
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7606 - loss: 149.6102 - val_accuracy: 0.7375 - val_loss: 177.1340
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7666 - loss: 146.6564 - val_accuracy: 0.7775 - val_loss: 180.1479
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7591 - loss: 172.8664 - val_accuracy: 0.6350 - val_loss: 235.6084
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7503 - loss: 158.8071 - val_accuracy: 0.8087 - val_loss: 218.8692
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7572 - loss: 159.6279 - val_accuracy: 0.7950 - val_loss: 186.7101
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7694 - loss: 153.9398 - val_accuracy: 0.7850 - val_loss: 194.5264
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7763 - loss: 166.1386 - val_accuracy: 0.7088 - val_loss: 165.7222
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7606 - loss: 175.3149 - val_accuracy: 0.7150 - val_loss: 178.8142
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7503 - loss: 180.6211 - val_accuracy: 0.7375 - val_loss: 174.8978
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7616 - loss: 133.7606 - val_accuracy: 0.7287 - val_loss: 181.6678
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7412 - loss: 209.6991 - val_accuracy: 0.6913 - val_loss: 196.6939
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7613 - loss: 169.8153 - val_accuracy: 0.6925 - val_loss: 176.6897
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7619 - loss: 150.8178 - val_accuracy: 0.7613 - val_loss: 165.6778
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7744 - loss: 132.3148 - val_accuracy: 0.7550 - val_loss: 155.3439
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7653 - loss: 142.5794 - val_accuracy: 0.6425 - val_loss: 220.7070
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7597 - loss: 156.3610 - val_accuracy: 0.7750 - val_loss: 165.6755
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7569 - loss: 145.6312 - val_accuracy: 0.8000 - val_loss: 178.7780

# %% [markdown]
# Accuracy para entrenamiento y validación no se ven muy bien

# %% [markdown]
# Grafiquemos cómo se ve esto en cada época

# %%
plt.figure(figsize=(14,5))

plt.subplot(121)

plt.plot(mynet.history['loss'], label = 'train') #mynet.history guarda la historia en cada época de la red
plt.plot(mynet.history['val_loss'],'-.m', label = 'validation')
plt.ylabel('Loss', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(loc='upper right', fontsize = 12)

plt.subplot(122)

plt.plot(mynet.history['accuracy'], label = 'train')
plt.plot(mynet.history['val_accuracy'], '-.m', label = 'validation')
plt.ylabel('Accuracy', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(fontsize = 12)
plt.subplots_adjust(wspace=0.5)

#plt.show()

#plt.savefig('FirstNN.png', dpi= 300)

# %% [markdown]
# ### Diagnóstico
#
# El accuracy salió mucho peor de lo esperado. Antes de seguir:
#
# 1. Corra `X.describe()` en la celda de abajo y miren los rangos (min, max, mean) de las distintas columnas.
# 2. ¿Ve algo que podría estar afectando el entrenamiento por gradiente descendiente?
#     Respuesta: Sí, la gran disparidad en los rangos de las características afecta gravemente el entrenamiento por gradiente descendente.
# 3. Le parece que la curva de la pérdida es suficiente para el diagnóstico del modelo?
#     Respuesta: Sí, la curva de pérdida es suficiente. Una pérdida inicial altísima, que se estabiliza de forma inestable y elevada, indica claramente un problema fundamental (en este caso, la falta de escalado).

# %%
X.describe()
# Out:
#                 ID            MET       METphi            P1            P2  \
# count  5000.000000    5000.000000  5000.000000  5.000000e+03  5.000000e+03
# mean   2499.500000   64071.074332    -0.028916  3.301357e+05  1.540486e+05
# std    1443.520003   60525.122480     1.819257  3.068202e+05  1.149469e+05
# min       0.000000     290.756000    -3.141010  3.857940e+04  2.825400e+04
# 25%    1249.750000   24352.375000    -1.619905  1.369522e+05  8.883690e+04
# 50%    2499.500000   46814.400000    -0.055612  2.263525e+05  1.182015e+05
# 75%    3749.250000   83032.350000     1.537323  4.077158e+05  1.771265e+05
# max    4999.000000  692674.000000     3.141130  3.186360e+06  1.276710e+06
#
#                 P3           P4            P5            P6           P7  \
# count  5000.000000  5000.000000  5.000000e+03  5.000000e+03  5000.000000
# mean     -0.039812    -0.003049  2.526283e+05  1.079653e+05    -0.029918
# std       1.361762     1.814855  2.638514e+05  8.138121e+04     1.438673
# min      -4.110220    -3.140710  0.000000e+00  0.000000e+00    -4.668790
# 25%      -1.035570    -1.574213  1.007050e+05  6.320943e+04    -1.059270
# 50%      -0.038731    -0.009037  1.658985e+05  8.581595e+04    -0.056810
# 75%       0.943598     1.542370  2.999058e+05  1.238520e+05     1.028055
# max       4.141410     3.138540  3.587700e+06  1.146330e+06     4.559150
#
#                 P8            P9            P10          P11          P12  \
# count  5000.000000  5.000000e+03    5000.000000  5000.000000  5000.000000
# mean      0.007323  2.096800e+05   74114.709700    -0.024853     0.011727
# std       1.828283  2.506651e+05   46675.655162     1.569410     1.793678
# min      -3.140530  0.000000e+00       0.000000    -4.520250    -3.141480
# 25%      -1.599617  7.488228e+04   46165.375000    -1.108390    -1.532478
# 50%       0.012737  1.277135e+05   62167.100000    -0.023321     0.006687
# 75%       1.601880  2.406498e+05   89065.300000     1.048617     1.553310
# max       3.139200  2.800410e+06  788338.000000     4.798090     3.139020
#
#                 P13            P14          P15          P16  Total_products  \
# count  5.000000e+03    5000.000000  5000.000000  5000.000000     5000.000000
# mean   1.703778e+05   54046.489280     0.010116     0.042704        6.245400
# std    2.352279e+05   33795.723384     1.587146     1.760070        2.157709
# min    0.000000e+00       0.000000    -4.616550    -3.136130        1.000000
# 25%    5.480870e+04   33959.400000    -1.050477    -1.424080        5.000000
# 50%    9.259335e+04   47278.800000     0.000000     0.000000        6.000000
# 75%    1.831228e+05   66846.300000     1.085627     1.521765        7.000000
# max    2.503590e+06  481884.000000     4.730480     3.139660       13.000000
#
#            Total_b     Total_j      Total_g  Total_leptons
# count  5000.000000  5000.00000  5000.000000    5000.000000
# mean      1.418200     4.49240     0.030400       0.304400
# std       0.955767     2.03479     0.171702       0.519418
# min       0.000000     0.00000     0.000000       0.000000
# 25%       1.000000     3.00000     0.000000       0.000000
# 50%       1.000000     4.00000     0.000000       0.000000
# 75%       2.000000     6.00000     0.000000       1.000000
# max       6.000000    13.00000     1.000000       3.000000

# %% [markdown]
# ### Nos olvidamos de escalar (por qué es necesario??)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %% [markdown]
# Escalamos sólo los datos del set entrenamiento (para evitar leakage)

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
Xst_train = scaler.transform(X_train)
Xst_val = scaler.transform(X_val)
Xst_test = scaler.transform(X_test)

# %% [markdown]
# ### Reentrenamos la red

# %%
model_st = Sequential()
model_st.add(Dense(20, activation='relu', input_shape=(24,)))
model_st.add(Dense(20, activation='relu'))
model_st.add(Dense(1, activation='sigmoid'))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model_st.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

mynet_st = model_st.fit(
    Xst_train, y_train, validation_data=(Xst_val, y_val),
    epochs=100, batch_size=200, verbose=0) #verbose=0 para no mostrar el resultado en cada epoca
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
plt.figure(figsize=(14,5))

plt.subplot(121)

plt.plot(mynet_st.history['loss'], label = 'train')
plt.plot(mynet_st.history['val_loss'],'-.m', label = 'validation')
plt.ylabel('Loss', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(loc='upper right', fontsize = 12)

plt.subplot(122)

plt.plot(mynet_st.history['accuracy'], label = 'train')
plt.plot(mynet_st.history['val_accuracy'], '-.m', label = 'validation')
plt.ylabel('Accuracy', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(fontsize = 12)
plt.subplots_adjust(wspace=0.5)
#plt.show()

#plt.savefig('ScaledNN.png', dpi= 300)

# %% [markdown]
# #### Ahora se ve mucho mejor el comportamiento de la red, y además se alcanza un accuracy similar a lo que obtuvimos con SVMs
#
# Esto es común para datos tabulares, que tienen relaciones más simples y en general no contienen demasiados datos. Las NN funcionan mejor para datos más complejos, como audio, imágenes, texto

# %% [markdown]
# ### Diagnóstico
#
# Mire las curvas de loss y accuracy  (train vs. validación, con datos escalados).
#
# 1. ¿Hay separación entre las curvas de train y validación? ¿Es una separación que se mantiene estable, o una que crece con las épocas?
#     Respuesta: Sí, clara y creciente, especialmente en la pérdida.
# 2. ¿esto califica como overfitting severo, overfitting leve, o no hay overfitting? Justifique mirando específicamente sus números, no una regla general.
#     Respuesta: Leve a moderado. Pérdida de validación sube y accuracy se estanca, mientras train mejora.
# 3. Según su diagnóstico, ¿tiene sentido aplicar regularización acá, o el modelo ya está bien como está?
#     Respuesta: Sí, el overfitting lo indica (Dropout/Early Stopping).

# %% [markdown]
# ### Ahora pruebe usted
#
# La red original cuenta con dos capas ocultas de 20 neuronas cada una, ReLU, y salida sigmoide, entrenada con datos escalados. Usando ese mismo código como plantilla, construya y entrene tres variantes, una a la vez:
#
# 1. **Agregue una tercera capa oculta** (de 20 neuronas también). ¿Mejora, empeora, o no cambia mucho el accuracy de validación? ¿Por qué creen que pasa eso en este dataset específico?
#
# 2. **Cambie el tamaño de las capas ocultas** a algo mucho más chico (5 neuronas) y después a algo mucho más grande (100 neuronas). ¿Cuál entrena más lento? ¿Cuál muestra más señales de sobreajuste en las curvas de loss?
#
# 3. **Cambie la activación** de las capas ocultas de `relu` a `tanh`. Usen `dir(keras.activations)` si quieren ver más opciones. ¿Cambia la velocidad de convergencia?
#
# Rellene la tabla de comparación
#
# | Variante | val_accuracy | val_loss | Comentario |
# |---|---|---|---|
# | Baseline (2 capas x 20, relu) | | | |
# | 3 capas ocultas | | | |
# | Capas de 5 neuronas | | | |
# | Capas de 100 neuronas | | | |
# | Activación tanh | | | |
#
# (Respuestas más abajo)

# %% [markdown]
# ### Variante 1: Agregando una tercera capa oculta (20 neuronas)

# %%
model_3_layers = Sequential()
model_3_layers.add(Dense(20, activation='relu', input_shape=(24,)))
model_3_layers.add(Dense(20, activation='relu'))
model_3_layers.add(Dense(20, activation='relu')) # Tercera capa oculta
model_3_layers.add(Dense(1, activation='sigmoid'))

optimizer_3_layers = tf.keras.optimizers.Adam(learning_rate=0.001)
model_3_layers.compile(loss='binary_crossentropy', optimizer=optimizer_3_layers, metrics=['accuracy'])

mynet_3_layers = model_3_layers.fit(
    Xst_train, y_train, validation_data=(Xst_val, y_val),
    epochs=100, batch_size=200, verbose=0)

val_acc_3_layers = mynet_3_layers.history['val_accuracy'][-1]
val_loss_3_layers = mynet_3_layers.history['val_loss'][-1]

print(f"Validation Accuracy (3 capas): {val_acc_3_layers:.4f}")
print(f"Validation Loss (3 capas): {val_loss_3_layers:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Validation Accuracy (3 capas): 0.9375
# Validation Loss (3 capas): 0.2254

# %% [markdown]
# ### Variante 2: Cambiando el tamaño de las capas ocultas (5 neuronas)

# %%
model_5_neurons = Sequential()
model_5_neurons.add(Dense(5, activation='relu', input_shape=(24,)))
model_5_neurons.add(Dense(5, activation='relu'))
model_5_neurons.add(Dense(1, activation='sigmoid'))

optimizer_5_neurons = tf.keras.optimizers.Adam(learning_rate=0.001)
model_5_neurons.compile(loss='binary_crossentropy', optimizer=optimizer_5_neurons, metrics=['accuracy'])

mynet_5_neurons = model_5_neurons.fit(
    Xst_train, y_train, validation_data=(Xst_val, y_val),
    epochs=100, batch_size=200, verbose=0)

val_acc_5_neurons = mynet_5_neurons.history['val_accuracy'][-1]
val_loss_5_neurons = mynet_5_neurons.history['val_loss'][-1]

print(f"Validation Accuracy (5 neuronas): {val_acc_5_neurons:.4f}")
print(f"Validation Loss (5 neuronas): {val_loss_5_neurons:.4f}")
# Out:
# Validation Accuracy (5 neuronas): 0.9400
# Validation Loss (5 neuronas): 0.1367

# %% [markdown]
# ### Variante 3: Cambiando el tamaño de las capas ocultas (100 neuronas)

# %%
model_100_neurons = Sequential()
model_100_neurons.add(Dense(100, activation='relu', input_shape=(24,)))
model_100_neurons.add(Dense(100, activation='relu'))
model_100_neurons.add(Dense(1, activation='sigmoid'))

optimizer_100_neurons = tf.keras.optimizers.Adam(learning_rate=0.001)
model_100_neurons.compile(loss='binary_crossentropy', optimizer=optimizer_100_neurons, metrics=['accuracy'])

mynet_100_neurons = model_100_neurons.fit(
    Xst_train, y_train, validation_data=(Xst_val, y_val),
    epochs=100, batch_size=200, verbose=0)

val_acc_100_neurons = mynet_100_neurons.history['val_accuracy'][-1]
val_loss_100_neurons = mynet_100_neurons.history['val_loss'][-1]

print(f"Validation Accuracy (100 neuronas): {val_acc_100_neurons:.4f}")
print(f"Validation Loss (100 neuronas): {val_loss_100_neurons:.4f}")
# Out:
# Validation Accuracy (100 neuronas): 0.9225
# Validation Loss (100 neuronas): 0.4091

# %% [markdown]
# ### Variante 4: Cambiando la activación a tanh

# %%
model_tanh_act = Sequential()
model_tanh_act.add(Dense(20, activation='tanh', input_shape=(24,)))
model_tanh_act.add(Dense(20, activation='tanh'))
model_tanh_act.add(Dense(1, activation='sigmoid'))

optimizer_tanh_act = tf.keras.optimizers.Adam(learning_rate=0.001)
model_tanh_act.compile(loss='binary_crossentropy', optimizer=optimizer_tanh_act, metrics=['accuracy'])

mynet_tanh_act = model_tanh_act.fit(
    Xst_train, y_train, validation_data=(Xst_val, y_val),
    epochs=100, batch_size=200, verbose=0)

val_acc_tanh_act = mynet_tanh_act.history['val_accuracy'][-1]
val_loss_tanh_act = mynet_tanh_act.history['val_loss'][-1]

print(f"Validation Accuracy (tanh): {val_acc_tanh_act:.4f}")
print(f"Validation Loss (tanh): {val_loss_tanh_act:.4f}")
# Out:
# Validation Accuracy (tanh): 0.9325
# Validation Loss (tanh): 0.1907

# %% [markdown]
# 1. **Agregue una tercera capa oculta** (de 20 neuronas también). ¿Mejora, empeora, o no cambia mucho el accuracy de validación? ¿Por qué creen que pasa eso en este dataset específico?
#     Respuesta: El accuracy de validación se mantiene igual (0.9375) y el loss de validación empeora ligeramente (0.1762 a 0.2254). Para este dataset, más capas no añaden beneficio significativo y aumentan la complejidad.
#
# 2. **Cambie el tamaño de las capas ocultas** a algo mucho más chico (5 neuronas) y después a algo mucho más grande (100 neuronas). ¿Cuál entrena más lento? ¿Cuál muestra más señales de sobreajuste en las curvas de loss?
#     Repuesta: Con 5 neuronas, entrena más rápido y el val_accuracy mejora a 0.9400 con un val_loss menor (0.1367). Con 100 neuronas, entrena más lento, el val_accuracy empeora a 0.9225 y el val_loss aumenta a 0.4091, mostrando más sobreajuste.
#
# 3. **Cambie la activación** de las capas ocultas de `relu` a `tanh`. Usen `dir(keras.activations)` si quieren ver más opciones. ¿Cambia la velocidad de convergencia?
#     Respuesta: El val_accuracy disminuye a 0.9325 y el val_loss aumenta a 0.1907. La velocidad de convergencia podría ser similar, pero el rendimiento es ligeramente inferior a `relu` para este problema, posiblemente por problemas de vanishing gradients.
#
# ### Resultados de las variantes:
#
# | Variante | val_accuracy | val_loss | Comentario |
# |---|---|---|---|
# | Baseline (2 capas x 20, relu) | 0.9375 | 0.1762 | Buena base, pero con algo de sobreajuste. |
# | 3 capas ocultas | 0.9375 | 0.2254 | El accuracy no mejora y el loss de validación empeora. Más capas no son beneficiosas para este dataset. |
# | Capas de 5 neuronas | 0.9400 | 0.1367 | Mejora ligeramente el accuracy y el loss de validación. La red es más eficiente y menos propensa a sobreajuste. |
# | Capas de 100 neuronas | 0.9225 | 0.4091 | El accuracy y el loss de validación empeoran significativamente, mostrando sobreajuste. Entrena más lento y es demasiado compleja. |
# | Activación tanh | 0.9325 | 0.1907 | El accuracy y el loss de validación empeoran ligeramente. `tanh` tiene un rendimiento inferior a `relu` en este caso. |

# %% [markdown]
# ### Dropout

# %%
model_dropout = Sequential()

# Primera capa oculta, con el tamaño de la capa input especificado

model_dropout.add(Dense(20, activation='relu', input_shape=(24,)))

model_dropout.add(Dropout(0.2)) #fraccion de dropout

# Agregamos otra capa oculta y especificamos el tamaño

model_dropout.add(Dense(20, activation='relu'))

model_dropout.add(Dropout(0.2)) #fracción de dropout

#Agregamos capa de salida

model_dropout.add(Dense(1, activation='sigmoid'))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model_dropout.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
mynet_dropout = model_dropout.fit(Xst_train, y_train, validation_data= (Xst_val, y_val), epochs=100, batch_size=200, verbose=0)

# %%
plt.figure(figsize=(14,5))

plt.subplot(121)

plt.plot(mynet_dropout.history['loss'], label = 'train')
plt.plot(mynet_dropout.history['val_loss'],'-.m', label = 'validation')
plt.ylabel('Loss', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(loc='upper right', fontsize = 12)

plt.subplot(122)

plt.plot(mynet_dropout.history['accuracy'], label = 'train')
plt.plot(mynet_dropout.history['val_accuracy'], '-.m', label = 'validation')
plt.ylabel('Accuracy', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(fontsize = 12)
plt.subplots_adjust(wspace=0.5)

#plt.savefig('RegularizedNN.png', dpi= 300)
#plt.show()

# %% [markdown]
# ### Early Stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping

model_early = Sequential()
model_early.add(Dense(20, activation='relu', input_shape=(24,)))
model_early.add(Dense(20, activation='relu'))
model_early.add(Dense(1, activation='sigmoid'))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model_early.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

mynet_early = model_early.fit(
    Xst_train, y_train, validation_data=(Xst_val, y_val),
    epochs=100, batch_size=200, callbacks=[early_stop], verbose=0)

print(f"Se detuvo en la época: {len(mynet_early.history['loss'])}")
# Out:
# Se detuvo en la época: 28

# %%
plt.figure(figsize=(14,5))

plt.subplot(121)

plt.plot(mynet_early.history['loss'], label = 'train')
plt.plot(mynet_early.history['val_loss'],'-.m', label = 'validation')
plt.ylabel('Loss', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(loc='upper right', fontsize = 12)

plt.subplot(122)

plt.plot(mynet_early.history['accuracy'], label = 'train')
plt.plot(mynet_early.history['val_accuracy'], '-.m', label = 'validation')
plt.ylabel('Accuracy', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(fontsize = 12)
plt.subplots_adjust(wspace=0.5)

#plt.savefig('Regularized_Early_NN.png', dpi= 300)
#plt.show()

# %%
comparacion = pd.DataFrame([
    {"modelo": "escalado (sin regularizar)",
     "val_acc": mynet_st.history['val_accuracy'][-1],
     "val_loss": mynet_st.history['val_loss'][-1]},
    {"modelo": "escalado + dropout",
     "val_acc": mynet_dropout.history['val_accuracy'][-1],
     "val_loss": mynet_dropout.history['val_loss'][-1]},
    {"modelo": "escalado + early stopping",
     "val_acc": mynet_early.history['val_accuracy'][-1],
     "val_loss": mynet_early.history['val_loss'][-1]},
])
comparacion
# Out:
#                        modelo  val_acc  val_loss
# 0  escalado (sin regularizar)  0.92875  0.182258
# 1          escalado + dropout  0.94500  0.144418
# 2   escalado + early stopping  0.93625  0.157359

# %%
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix

modelos = {
    "sin regularizar": model_st,
    "dropout": model_dropout,
    "early stopping": model_early,
}

for nombre, modelo in modelos.items():
    y_pred_proba = modelo.predict(Xst_test, verbose=0).ravel()
    y_pred = (y_pred_proba > 0.5).astype(int)

    print(f"=== {nombre} ===")
    print(classification_report(y_test, y_pred, target_names=["ttbar", "4top"]))
    print(f"AUC-ROC: {roc_auc_score(y_test, y_pred_proba):.4f}")
    print("Matriz de confusión:")
    print(confusion_matrix(y_test, y_pred))
    print()
# Out:
# === sin regularizar ===
#               precision    recall  f1-score   support
#
#        ttbar       0.96      0.97      0.97       838
#         4top       0.84      0.81      0.83       162
#
#     accuracy                           0.94      1000
#    macro avg       0.90      0.89      0.90      1000
# weighted avg       0.94      0.94      0.94      1000
#
# AUC-ROC: 0.9733
# Matriz de confusión:
# [[813  25]
#  [ 30 132]]
#
# === dropout ===
#               precision    recall  f1-score   support
#
#        ttbar       0.97      0.97      0.97       838
#         4top       0.85      0.86      0.86       162
#
#     accuracy                           0.95      1000
#    macro avg       0.91      0.91      0.91      1000
# weighted avg       0.95      0.95      0.95      1000
#
# AUC-ROC: 0.9780
# Matriz de confusión:
# [[814  24]
#  [ 23 139]]
#
# === early stopping ===
#               precision    recall  f1-score   support
#
#        ttbar       0.97      0.97      0.97       838
#         4top       0.84      0.83      0.84       162
#
#     accuracy                           0.95      1000
#    macro avg       0.91      0.90      0.90      1000
# weighted avg       0.95      0.95      0.95      1000
#
# AUC-ROC: 0.9755
# Matriz de confusión:
# [[813  25]
#  [ 27 135]]

# %%
comparacion = pd.DataFrame([
    {
        "modelo": nombre,
        "val_acc": modelo.evaluate(Xst_val, y_val, verbose=0)[1],
        "test_auc": roc_auc_score(y_test, modelo.predict(Xst_test, verbose=0).ravel()),
        "epocas": len(modelo.history.history['loss']) if hasattr(modelo, 'history') else None,
    }
    for nombre, modelo in modelos.items()
])
comparacion
# Out:
#             modelo  val_acc  test_auc  epocas
# 0  sin regularizar  0.92875  0.973290     100
# 1          dropout  0.94500  0.977960     100
# 2   early stopping  0.93625  0.975463      28

# %% [markdown]
# ### Después de correr ambas: reflexión
#
# Mire los números reales de dropout y early stopping.
#
# 1. Esperaba ese resultado? Explique
#     Respuesta: Sí, en general. Dropout y Early Stopping son técnicas efectivas para mitigar el overfitting, y los resultados muestran una mejora en el `val_acc` y una reducción en el `val_loss` comparado con el modelo sin regularizar. Especialmente el `val_loss` de dropout mejoró significativamente.
# 2. Dropout actúa *durante* el entrenamiento (apagando neuronas en cada paso). Early stopping actúa *deteniendo* el entrenamiento en un punto. ¿Por qué una de las dos estrategias podría funcionar mejor que la otra en este dataset específico, dado su tamaño y la arquitectura que están usando?
#     Respuesta: Para este dataset y arquitectura, Dropout (`val_acc`: 0.9450, `val_loss`: 0.1444) parece haber funcionado mejor que Early Stopping (`val_acc`: 0.9362, `val_loss`: 0.1574) en la validación. Esto podría deberse a que Dropout introduce una mayor robustez en el modelo al forzar a la red a no depender de ninguna neurona en particular, lo que es beneficioso en modelos que tienden a sobreajustar. Early Stopping es más directo al prevenir el sobreajuste al detener el entrenamiento a tiempo, pero no modifica la estructura de aprendizaje intrínseca como lo hace Dropout.
# 3. ¿Tendría sentido combinar ambas (dropout + early stopping) en vez de elegir una sola? ¿Por qué sí o por qué no?
#     Respuesta: Sí, definitivamente. Combinar Dropout y Early Stopping es una práctica común y a menudo muy efectiva. Dropout regulariza el modelo durante el entrenamiento, mientras que Early Stopping evita que se sobreajuste en las últimas épocas. Ambas técnicas abordan diferentes aspectos del overfitting y pueden complementarse para lograr un mejor rendimiento y generalización del modelo.
# 4. Pruebe distintos valores de dropout y early stopping y discuta cómo cambian los resultados.

# %% [markdown]
# ### Optimización de hiperparámetros
#
# Usaremos [`keras_tuner`](https://keras.io/keras_tuner/) para optimizar los hiperparámetros de la arquitectura de la red

# %% [markdown]
# ### Antes de correr la búsqueda
#
# Con lo que ya sabe del dataset y de los experimentos anteriores, responda:
#
# - ¿Cuántas capas ocultas cree que va a preferir el mejor modelo?
#     Respuesta: Probablemente 1 o 2 capas. Experimentos previos sugieren que más capas no mejoran y pueden empeorar el rendimiento.
# - ¿Dropout va a terminar en 0.0 o en un valor alto?
#     Respuesta: Un valor mayor que 0.0 (probablemente alrededor de 0.1-0.2). La regularización por Dropout ha demostrado ser efectiva contra el sobreajuste leve a moderado.
# - ¿El learning rate óptimo va a ser más cercano a 0.0001 o a 0.01?
#     Respuesta: Más cercano a 0.0001. Un learning rate de 0.01 suele ser demasiado alto, y un valor más pequeño puede ayudar a una convergencia más estable.

# %%
pip install keras-tuner  #(correr una vez en Colab)
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.8-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (3.13.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (26.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (2.32.4)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: grpcio in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (1.82.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (5.29.6)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio->keras-tuner) (4.16.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (3.16.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.19.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (2026.6.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras->keras-tuner) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras->keras-tuner) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Downloading keras_tuner-1.4.8-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 6.1 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.8 kt-legacy-1.0.5

# %%
import keras_tuner as kt

def build_model_tuner(hp):
    model = Sequential()

    #prueba con ndistintos numeros de neuronas, desde 8 a 64, cada 8,
    n_neurons = hp.Int("n_neurons", min_value=8, max_value=64, step=8)
    # activation = hp.Choice("activation", values=["relu", "tanh"])

    #construye la capa con la cantidad de neuronas que fijo en el paso anterior (cada capa con el mismo numero de neuronas)
    model.add(Dense(n_neurons, activation='relu', input_shape=(24,)))

    #numero de capas ocultas (1, 2, o 3)
    n_hidden = hp.Int("n_hidden", min_value=1, max_value=3)
    for i in range(n_hidden - 1):
        model.add(Dense(n_neurons, activation='relu'))

    #tasa de dropout (0.1-0.5, en pasos de 0.1)
    dropout_rate = hp.Float("dropout_rate", min_value=0.0, max_value=0.5, step=0.1)
    if dropout_rate > 0:
        model.add(Dropout(dropout_rate))
    #la capa de salida queda fija, para la clasificacion binaria
    model.add(Dense(1, activation='sigmoid'))

    #tasa de aprendizaje, entre 0.0001 y 0.01
    learning_rate = hp.Float("learning_rate", min_value=1e-4, max_value=1e-2, sampling="log")
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

    return model

#prueba solo combinaciones aleatorias para reducir costo computacional
tuner = kt.RandomSearch(
    build_model_tuner,
    objective="val_accuracy",
    max_trials=15,          # número de combinaciones a probar
    executions_per_trial=1,
    directory="tuner_resultados",
    project_name="particle_id",
)

tuner.search(
    Xst_train, y_train,
    validation_data=(Xst_val, y_val),
    epochs=30,
    batch_size=200,
    verbose=1,
)
# Out:
# Trial 15 Complete [00h 00m 08s]
# val_accuracy: 0.9449999928474426
#
# Best val_accuracy So Far: 0.949999988079071
# Total elapsed time: 00h 02m 30s

# %%
# Mejor modelo encontrado
mejores_hp = tuner.get_best_hyperparameters(1)[0]
print("Mejores hiperparámetros:")
for param in mejores_hp.values:
    print(f"  {param}: {mejores_hp.values[param]}")
# Out:
# Mejores hiperparámetros:
#   n_neurons: 32
#   n_hidden: 3
#   dropout_rate: 0.4
#   learning_rate: 0.0013479722858835714

# %% [markdown]
# ### Evaluamos finalmente el modelo con el set de prueba, que sólo se usa en el paso final

# %%
mejor_modelo = tuner.get_best_models(1)[0]
scores = mejor_modelo.evaluate(Xst_test, y_test, verbose=0)
print(f"\nAccuracy en test: {scores[1]:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 18 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Accuracy en test: 0.9460

# %%
# Resumen de los mejores trials
tuner.results_summary(num_trials=5)
# Out:
# Results summary
# Results in tuner_resultados/particle_id
# Showing 5 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 07 summary
# Hyperparameters:
# n_neurons: 32
# n_hidden: 3
# dropout_rate: 0.4
# learning_rate: 0.0013479722858835714
# Score: 0.949999988079071
#
# Trial 09 summary
# Hyperparameters:
# n_neurons: 32
# n_hidden: 3
# dropout_rate: 0.30000000000000004
# learning_rate: 0.003785395564595355
# Score: 0.9474999904632568
#
# Trial 01 summary
# Hyperparameters:
# n_neurons: 40
# n_hidden: 2
# dropout_rate: 0.30000000000000004
# learning_rate: 0.0010918942857643605
# Score: 0.9462500214576721
#
# Trial 06 summary
# Hyperparameters:
# n_neurons: 40
# n_hidden: 2
# dropout_rate: 0.1
# learning_rate: 0.0002816574185995002
# Score: 0.9449999928474426
#
# Trial 10 summary
# Hyperparameters:
# n_neurons: 56
# n_hidden: 3
# dropout_rate: 0.4
# learning_rate: 0.009964547779368166
# Score: 0.9449999928474426

# %% [markdown]
# ### Mire los 5 mejores trials, no solo el ganador
#
#
# 1. ¿Hay algún empate o casi-empate en el score entre dos trials? Compare sus arquitecturas (n_neurons, n_hidden) y su dropout_rate uno al lado del otro, ¿qué tan distintos son entre sí?
#     Respuesta: Sí, hay casi-empates (Trial 07 vs 09, Trial 06 vs 10). Las arquitecturas pueden ser similares (3 capas, 32 neuronas, dropout 0.4 vs 0.3) o distintas (Trial 06: 2 capas, 40 neuronas, dropout 0.1 vs Trial 10: 3 capas, 56 neuronas, dropout 0.4). Esto indica que varias combinaciones de complejidad y regularización pueden lograr rendimientos parecidos.
#
# 2. Si encuentra un caso así, ¿qué le dice eso sobre la relación entre tamaño de red y necesidad de regularización? ¿es dropout algo que "siempre ayuda", o depende de si la arquitectura ya es lo suficientemente chica como para no necesitarlo?
#     Respuesta: Dropout ayuda a robustecer la red, independientemente del tamaño, evitando el sobreajuste incluso en arquitecturas no "masivas".
#
# 3. Si tuviera que elegir entre dos modelos con score casi igual pero muy distintos en complejidad, ¿cuál elige para poner en producción y por qué? (piense en costo de cómputo, riesgo de overfitting futuro, interpretabilidad)
#     Respuesta: Elegiría el modelo de menor complejidad para producción, por su menor costo computacional y menor riesgo de sobreajuste futuro.
#
# 4. Compare el mejor modelo de la búsqueda automática contra su mejor intento manual (dropout o early stopping). ¿Vale la pena el costo computacional de la búsqueda para esa diferencia?
#     Respuesta: El mejor modelo automático (0.9500) solo superó ligeramente al manual (0.9450). El costo de la búsqueda automática podría no justificarse para esta pequeña mejora.

# %% [markdown]
# ### Reflexión final
#
# 1. A lo largo de este notebook probó varios modelos: sin escalar, escalado, con dropout, con early stopping, y el resultado de la búsqueda automática de hiperparámetros. ¿Cuál de todos eligiría como el modelo final, y por qué? Use números concretos de sus tablas, no solo accuracy.
#     Respuesta: Elegiría el mejor modelo de la búsqueda automática (`val_accuracy: 0.9500`, `test_accuracy: 0.9460`), por su mejor rendimiento en validación y generalización.
#
# 2. El SVM del notebook anterior llegó a 94-95%. ¿Su mejor red neuronal lo superó? Si la diferencia es chica, ¿vale la pena toda la complejidad extra (arquitectura, regularización, búsqueda de hiperparámetros) por esa ganancia?
#     Respuesta: El mejor modelo NN (`test_accuracy: 0.9460`) logró un rendimiento similar al SVM (94-95%). Por una ganancia marginal, la complejidad adicional de la NN podría no justificarse.
#
# 3. Comparen el salto de accuracy entre "sin escalar → escalado" contra el salto entre "escalado sin regularizar → mejor modelo de la búsqueda de hiperparámetros". ¿Cuál salto fue más grande? ¿Qué les dice eso sobre dónde conviene invertir tiempo primero cuando entrenan una red nueva?
#     Respuesta: El salto de `accuracy` fue mayor de "sin escalar" (~0.80) a "escalado" (0.92875, ~13 puntos), que de "escalado sin regularizar" (0.92875) al "mejor modelo de búsqueda de hiperparámetros" (0.9500, ~2 puntos). Esto indica que la preparación de datos (escalado) es el paso más crítico e impactante.
